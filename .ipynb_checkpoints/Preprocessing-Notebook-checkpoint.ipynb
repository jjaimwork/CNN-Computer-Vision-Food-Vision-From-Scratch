# %%
### OBJECTIVES ###

# All in random
# Select 10 classes 
# Generate training samples, test samples
# Generate 1 percent of the data 10 classes
# Generate 10 percent of the data 5 classes
# Generate 100 percent of the data 10 classes
# Generate 10 percent of all classes


import os
from glob import glob
import numpy as np
from distutils.dir_util import copy_tree
#from sklearn.model_selection import train_test_split
import shutil
import random
#import pandas as pd
from collections import ChainMap

import json
#from tqdm.notebook import tqdm

# %% [markdown]
# ### Select 10 classes

# %%
# Set the dataset dir
dataset_dir = '../../Datasets/food-101/images/'

# %%
# Get the classlist
class_list_all = glob(os.path.join(dataset_dir, '*',))
class_list_all = [i.split('\\')[-1] for i in class_list_all]
class_list_all;

# %%
# generate classes     
def generate_classlist_all(dataset_dir):
    '''
    Generates a list of all classes based from the looped data.
    
    Parameters
    ------
    dataset_dir - dataset directory
    '''
    
    class_list_all = glob(os.path.join(dataset_dir, '*',))
    class_list_all = [i.split('\\')[-1] for i in class_list_all]
    return class_list_all

# %%
# generate class
def generate_classlist(class_list, num_class):
    '''
    Generates a list of n classes.
    
    Parameters
    ------
    class_list - a list of classes
    num_classes - amount of classes you want
    '''
    counter = 0
    class_list_ = []
    while counter != num_class:
        if np.random.choice(class_list) not in class_list_:        
            class_list_.append(np.random.choice(class_list))
            counter +=1
    return class_list_

# %%
def loop_through_files(dataset_dir):
    '''
    Loops through the directory and prints out the how much data within
    
    Parameters
    ------
    data_dir(str) - dataset directory
    '''
    total_files = []
    for dirpath, dirnames, filenames in os.walk(data_dir):
        print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
        total_files.append(len(filenames))
    return sum(total_files)

# %% [markdown]
# ### Generating a dictionary

# %%
# Append each class file in a dictionary list
# get the length of the string
# random choice of 10%

# %%
def generate_dict_data(classlist, dataset_dir):
    '''
    Generates a dictionary of class along with its list of data
    
    Parameters
    ------
    classlist - list of classes
    dataset_dir - dataset directory
    '''
    
    dict_ = {}
    for class_ in classlist:
        dict_[class_] = []
    for class_name, list_ in dict_.items():
        for filenames in os.listdir(dataset_dir + class_name):
            list_.append(filenames)
    return dict_

# %%
def generate_train_test_data(dict_files, percentage_test):
    '''
    Generates a train-test split with the percentage given.
    
    Parameters
    ------
    dict_files - dictionary of classes along with its list of data
    percent_test - percent of test data to generate
    
    Usage
    ----
    x, y = generate_train_test_data(dict_files, percentage_test)
    '''
    test_data_all = []
    train_data_all = []
    
    percentage = percentage_test / 100
    
    for name_, data_ in dict_files.items():
        test_data_all.append({name_ : dict_files[name_][(int(len(dict_files[name_])*percentage)):]})
        train_data_all.append({name_ : dict_files[name_][:(int(len(dict_files[name_])*percentage))]})
            
    # combines lists into a single dictionary        
    test_data_all = dict(ChainMap(*test_data_all))
    train_data_all = dict(ChainMap(*train_data_all))        
    return test_data_all, train_data_all

# %%
loop_through_files('Food-Vision-REDO/datasets/food_101_10_percent/')
# Out:
# There are 2 directories and 0 images in 'Food-Vision-REDO/datasets/food_101_10_percent/'.
# There are 101 directories and 0 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\apple_pie'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\baby_back_ribs'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\baklava'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\beef_carpaccio'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\beef_tartare'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\beet_salad'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\beignets'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\bibimbap'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\bread_pudding'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\breakfast_burrito'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\bruschetta'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\caesar_salad'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\cannoli'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\caprese_salad'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\carrot_cake'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\ceviche'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\cheesecake'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\cheese_plate'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\chicken_curry'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\chicken_quesadilla'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\chicken_wings'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\chocolate_cake'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\chocolate_mousse'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\churros'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\clam_chowder'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\club_sandwich'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\crab_cakes'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\creme_brulee'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\croque_madame'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\cup_cakes'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\deviled_eggs'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\donuts'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\dumplings'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\edamame'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\eggs_benedict'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\escargots'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\falafel'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\filet_mignon'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\fish_and_chips'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\foie_gras'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\french_fries'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\french_onion_soup'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\french_toast'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\fried_calamari'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\fried_rice'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\frozen_yogurt'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\garlic_bread'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\gnocchi'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\greek_salad'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\grilled_cheese_sandwich'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\grilled_salmon'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\guacamole'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\gyoza'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\hamburger'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\hot_and_sour_soup'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\hot_dog'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\huevos_rancheros'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\hummus'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\ice_cream'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\lasagna'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\lobster_bisque'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\lobster_roll_sandwich'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\macaroni_and_cheese'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\macarons'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\miso_soup'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\mussels'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\nachos'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\omelette'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\onion_rings'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\oysters'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\pad_thai'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\paella'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\pancakes'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\panna_cotta'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\peking_duck'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\pho'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\pizza'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\pork_chop'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\poutine'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\prime_rib'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\pulled_pork_sandwich'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\ramen'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\ravioli'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\red_velvet_cake'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\risotto'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\samosa'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\sashimi'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\scallops'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\seaweed_salad'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\shrimp_and_grits'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\spaghetti_bolognese'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\spaghetti_carbonara'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\spring_rolls'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\steak'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\strawberry_shortcake'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\sushi'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\tacos'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\takoyaki'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\tiramisu'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\tuna_tartare'.
# There are 0 directories and 250 images in 'Food-Vision-REDO/datasets/food_101_10_percent/test\waffles'.
# There are 101 directories and 0 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\apple_pie'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\baby_back_ribs'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\baklava'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\beef_carpaccio'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\beef_tartare'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\beet_salad'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\beignets'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\bibimbap'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\bread_pudding'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\breakfast_burrito'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\bruschetta'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\caesar_salad'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\cannoli'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\caprese_salad'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\carrot_cake'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\ceviche'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\cheesecake'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\cheese_plate'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\chicken_curry'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\chicken_quesadilla'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\chicken_wings'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\chocolate_cake'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\chocolate_mousse'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\churros'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\clam_chowder'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\club_sandwich'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\crab_cakes'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\creme_brulee'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\croque_madame'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\cup_cakes'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\deviled_eggs'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\donuts'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\dumplings'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\edamame'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\eggs_benedict'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\escargots'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\falafel'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\filet_mignon'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\fish_and_chips'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\foie_gras'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\french_fries'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\french_onion_soup'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\french_toast'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\fried_calamari'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\fried_rice'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\frozen_yogurt'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\garlic_bread'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\gnocchi'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\greek_salad'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\grilled_cheese_sandwich'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\grilled_salmon'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\guacamole'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\gyoza'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\hamburger'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\hot_and_sour_soup'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\hot_dog'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\huevos_rancheros'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\hummus'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\ice_cream'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\lasagna'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\lobster_bisque'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\lobster_roll_sandwich'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\macaroni_and_cheese'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\macarons'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\miso_soup'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\mussels'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\nachos'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\omelette'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\onion_rings'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\oysters'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\pad_thai'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\paella'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\pancakes'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\panna_cotta'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\peking_duck'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\pho'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\pizza'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\pork_chop'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\poutine'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\prime_rib'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\pulled_pork_sandwich'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\ramen'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\ravioli'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\red_velvet_cake'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\risotto'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\samosa'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\sashimi'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\scallops'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\seaweed_salad'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\shrimp_and_grits'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\spaghetti_bolognese'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\spaghetti_carbonara'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\spring_rolls'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\steak'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\strawberry_shortcake'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\sushi'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\tacos'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\takoyaki'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\tiramisu'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\tuna_tartare'.
# There are 0 directories and 75 images in 'Food-Vision-REDO/datasets/food_101_10_percent/train\waffles'.
# 32825

# %% [markdown]
# ### Train and Test Data
# 750 on train
# 250 on test

# %%
test = [34324], [23424]
test
# Out:
# ([34324], [23424])

# %%
# get 75% of the data
# get 25 % of the data
# set them on test and train

# %%
test_data_all = []
train_data_all = []

for food_name, food_data in food_10_dict.items():
    test_data_all.append({food_name : food_10_dict[food_name][750:]})
    train_data_all.append({food_name : food_10_dict[food_name][:750]})

# %%
test_data_all = dict(ChainMap(*test_data_all))
train_data_all = dict(ChainMap(*train_data_all))

# %%
len(test_data_all['spring_rolls']), len(train_data_all['spring_rolls'])
# Out:
# (250, 750)

# %%
source_folder = '../../Datasets/food-101/images/'
destination_folder = 'Food-Vision-REDO/datasets/food_101_10_percent/train/'
destination_folder_test = 'Food-Vision-REDO/datasets/food_101_10_percent/test/'

# %%
for i in class_list_all:
    os.mkdir(destination_folder_test+i)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# C:\Users\GILGAM~1\AppData\Local\Temp/ipykernel_18668/1008151413.py in <module>
#       1 for i in class_list_all:
# ----> 2     os.mkdir(destination_folder_test+i)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Food-Vision-REDO/datasets/food_101_10_percent/test/apple_pie'

# %%
for i in class_list_all:
    os.mkdir(destination_folder+i)

# %%
for food_names in class_list_all:
    for files in train_data_all[food_names][:75]:
        # construct full file path
        source = source_folder + food_names + '/' + files
        destination = destination_folder + food_names+ '/' + files
        # copy only files
        if os.path.isfile(source):
            shutil.copy(source, destination)
    print('Copy Done')
# Out:
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done
# Copy Done

# %%
for food_names in class_list_all:
    for files in test_data_all[food_names]:
        # construct full file path
        source = source_folder + food_names + '/' + files
        destination = destination_folder_test + food_names + '/' + files
        # copy only files
        if os.path.isfile(source):
            shutil.copy(source, destination)
    print('Copying Done')
# Out:
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done
# Copying Done

# %% [markdown]
# ### Generate 10% and 1% of the dataset

# %%
# generate 10
train_data_1_percent = []
train_data_10_percent = []

for food_name, food_data in food_10_dict.items():
    train_data_1_percent.append({food_name : food_10_dict[food_name][:10]})
    
for food_name, food_data in food_10_dict.items():
    train_data_10_percent.append({food_name : food_10_dict[food_name][:100]})

# %%
train_data_10_percent;

# %%
def generate_train_data(files, class_list, source_folder, destination_folder, total, percentage):
    '''
    Generates and copies files from a directory and its different classes for training to its training location
    
    Parameters:
    ---------
    files - individual files of the class
    source - location of original files
    destination - location on where it's going
    percentage - amount of training data we're going to generate
    total - total amount of the data
    class_list - list of classes for the destination folder
    '''
    
    percentage_total = int(total * percentage/100)

    for names in class_list:
        os.mkdir(destination_folder + names)
        for file in files[names][:percentage_total]:
            # construct full file path
            source = source_folder + names + '/' + file
            destination = destination_folder + names + '/' + file
            # copy only files
            if os.path.isfile(source):
                shutil.copy(source, destination)

# %%
generate_test_data(files=train_data_all, 
                   class_list=class_list_10, 
                   source_folder=source_folder, 
                   destination_folder='Food-Vision-REDO/datasets/1_percent_data_set/train/',
                   total=1000,
                   percentage=1)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# C:\Users\GILGAM~1\AppData\Local\Temp/ipykernel_17320/2146888981.py in <module>
# ----> 1 generate_test_data(files=train_data_all,
#       2                    class_list=class_list_10,
#       3                    source_folder=source_folder,
#       4                    destination_folder='Food-Vision-REDO/datasets/1_percent_data_set/train/',
#       5                    total=1000,
#
# C:\Users\GILGAM~1\AppData\Local\Temp/ipykernel_17320/2179571853.py in generate_test_data(files, class_list, source_folder, destination_folder, total, percentage)
#      16
#      17     for names in class_list:
# ---> 18         os.mkdir(destination_folder + names)
#      19         for file in files[names][:percentage_total]:
#      20             # construct full file path
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Food-Vision-REDO/datasets/1_percent_data_set/train/spring_rolls'

# %%
generate_train_data(files=train_data_all, 
                   class_list=class_list_10, 
                   source_folder=source_folder, 
                   destination_folder='Food-Vision-REDO/datasets/1_percent_data_set/train/',
                   total=1000,
                   percentage=1)
